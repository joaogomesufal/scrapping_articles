# %%
#Instalação das Dependencias
# !pip3 install beautifulsoup4 --user
# !pip3 install urllib3 --user
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/jhonxbatista/.local/lib/python3.5/site-packages (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in /home/jhonxbatista/.local/lib/python3.5/site-packages (from beautifulsoup4) (1.8)
# You are using pip version 18.1, however version 19.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: urllib3 in /home/jhonxbatista/.local/lib/python3.5/site-packages (1.22)
# You are using pip version 18.1, however version 19.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
#Importação das Dependencias 
import requests
from bs4 import BeautifulSoup
import wget

# %%
#Entrada da pesquisa
search_text = input('Insert what you serach for: ')
inf_limit = input('Insert inferior limit for articles: ')
upper_limit = input('Insert superior limit for articles: ')
pages_quantity = int(input('Insert quantity pages: '))

url_list = []
for i in range(0, pages_quantity):
    url = "https://scholar.google.com.br/scholar?start=" + str(i) + "0&q=" + str(search_text) + "&hl=pt-BR&as_sdt=0,5&as_ylo=" + str(inf_limit) + "&as_yhi=" + str(upper_limit)
    url_list.append(url)
print(url_list)
# Out:
# Insert what you serach for: Acessibilidade Web
# Insert inferior limit for articles: 2015
# Insert superior limit for articles: 2019
# Insert quantity pages: 10
# ['https://scholar.google.com.br/scholar?start=00&q=Acessibilidade Web&hl=pt-BR&as_sdt=0,5&as_ylo=2015&as_yhi=2019', 'https://scholar.google.com.br/scholar?start=10&q=Acessibilidade Web&hl=pt-BR&as_sdt=0,5&as_ylo=2015&as_yhi=2019', 'https://scholar.google.com.br/scholar?start=20&q=Acessibilidade Web&hl=pt-BR&as_sdt=0,5&as_ylo=2015&as_yhi=2019', 'https://scholar.google.com.br/scholar?start=30&q=Acessibilidade Web&hl=pt-BR&as_sdt=0,5&as_ylo=2015&as_yhi=2019', 'https://scholar.google.com.br/scholar?start=40&q=Acessibilidade Web&hl=pt-BR&as_sdt=0,5&as_ylo=2015&as_yhi=2019', 'https://scholar.google.com.br/scholar?start=50&q=Acessibilidade Web&hl=pt-BR&as_sdt=0,5&as_ylo=2015&as_yhi=2019', 'https://scholar.google.com.br/scholar?start=60&q=Acessibilidade Web&hl=pt-BR&as_sdt=0,5&as_ylo=2015&as_yhi=2019', 'https://scholar.google.com.br/scholar?start=70&q=Acessibilidade Web&hl=pt-BR&as_sdt=0,5&as_ylo=2015&as_yhi=2019', 'https://scholar.google.com.br/scholar?start=80&q=Acessibilidade Web&hl=pt-BR&as_sdt=0,5&as_ylo=2015&as_yhi=2019', 'https://scholar.google.com.br/scholar?start=90&q=Acessibilidade Web&hl=pt-BR&as_sdt=0,5&as_ylo=2015&as_yhi=2019']

# %%
#Iniciação do BeautifulSoup
def getArticlesInList(url_list):
    pdf_list_download = []
    for url in url_list:
        page  = requests.get(url)
        if(page.status_code == 200):
            print(url + " >> Requisição Realizada com sucesso!")
        elif(page.status_code == 500):
            print("Houve um erro interno, aguarde um momento e tente novamente.!")
        else:
            print("Houve um erro desconhecido")
        soup = BeautifulSoup(page.content, 'html.parser')
        list_results = soup.find_all('div', class_='gs_scl')
        #gs_or_ggsm
        for item_result in list_results :

            title = item_result.find(class_="gs_rt").get_text() if not (item_result.find(class_="gs_rt") is None) else False
            download_link = item_result.find(class_="gs_or_ggsm")
            download_link = download_link.find('a').get('href') if  not (download_link is None) else False
            print(download_link)
            is_pdf = item_result.find(class_="gs_ctg2").get_text() if not (item_result.find(class_="gs_ctg2") is None) else False
            is_pdf = True if is_pdf == '[PDF]' else False

            if(is_pdf):
                
                pdf_list_download.append({
                    'title': title,
                    'link': download_link
                })
    return pdf_list_download

# %%
link_list = getArticlesInList(url_list)
# Out:
# https://scholar.google.com.br/scholar?start=00&q=Acessibilidade Web&hl=pt-BR&as_sdt=0,5&as_ylo=2015&as_yhi=2019 >> Requisição Realizada com sucesso!
# http://www.br-ie.org/pub/index.php/rbie/article/viewFile/7131/5556
# http://www.each.usp.br/marceloeler/papers/Oliveira-Eler-SBSI2015.pdf
# http://www.scielo.mec.pt/scielo.php?pid=S1646-98952016000400007&script=sci_arttext&tlng=en
# http://www.fatecsaocaetano.edu.br/fascitech/index.php/fascitech/article/download/69/68
# False
# https://ieeexplore.ieee.org/iel7/7152443/7170350/07170414.pdf
# https://rcc.dcet.uab.pt/index.php/rcc/article/download/47/43
# https://repositorio.iscte-iul.pt/bitstream/10071/10911/1/Dissertacao_Ricardo_Carvalho_Completa_v1.pdf
# False
# False
# https://scholar.google.com.br/scholar?start=10&q=Acessibilidade Web&hl=pt-BR&as_sdt=0,5&as_ylo=2015&as_yhi=2019 >> Requisição Realizada com sucesso!
q=Acessibilidade Web&hl=pt-BR&as_sdt=0,5&as_ylo=2015&as_yhi=2019 >> Requisição Realizada com sucesso!
# http://periodicos.ufpb.br/index.php/biblio/article/download/24550/14649
# False
# http://www.teses.usp.br/teses/disponiveis/55/55134/tde-05102016-155830/publico/HumbertoLidioAntonelli_revisada.pdf
# https://www.revistas.ufg.br/ci/article/viewFile/31855/21869
# http://www.periodicos.usp.br/Rumores/article/download/105043/115197
# https://www.researchgate.net/profile/Renata_Magagnin/publication/305770385_ACESSIBILIDADE_ESPACIAL_NO_CENTRO_HISTORICO_DE_POCOS_DE_CALDAS_BRAZIL/links/57a08a6108ae94f454eb30b4/ACESSIBILIDADE-ESPACIAL-NO-CENTRO-HISTORICO-DE-POCOS-DE-CALDAS-BRAZIL.pdf
# False
# False
# https://repositorio.ufpb.br/jspui/bitstream/123456789/1882/1/ES30082017.pdf
# http://www.academia.edu/download/38997604/A_ampliacao_da_percepcao_da_interface_para_pessoas_com_deficiencia_visual_atraves_de_recursos_em_smartphones.pdf
# https://scholar.google.com.br/scholar?start=90&q=Acessibilidade Web&hl=pt-BR&as_sdt=0,5&as_ylo=2015&as_yhi=2019 >> Requisição Realizada com sucesso!
# https://www.fatecsaocaetano.edu.br/fascitech/index.php/fascitech/article/viewFile/15/14
# http://www.scielo.mec.pt/pdf/soc/v33/v33a07.pdf
# https://www.anptur.org.br/anais/anais/files/12/68.pdf
# https://www.lume.ufrgs.br/bitstream/handle/10183/122569/000971621.pdf?sequence=1&isAllowed=y
# https://revistas.ufpr.br/turismo/article/download/48408/31933
# https://www.researchgate.net/profile/Evandro_Manara_Miletto/publication/273459611_Rumo_a_uma_Biblioteca_de_Sons_Aberta_para_Experimentacao_Musical_Coletiva_na_Web/links/551020f00cf224726ac5226b/Rumo-a-uma-Biblioteca-de-Sons-Aberta-para-Experimentacao-Musical-Coletiva-na-Web.pdf
# http://www.egov.ufsc.br/portal/sites/default/files/document_3_0.pdf
# https://estudosemdesign.emnuvens.com.br/design/article/download/348/234
# False
# https://www.redalyc.org/html/3843/384351520005/

# %%
#Download do arquivo

for link in link_list: 
    try:
        name = link['title'].replace(' ', '_')[0:30] + '.pdf'
        r = requests.get(link['link'], allow_redirects=True)
        open(name, 'wb').write(r.content)
        print('Download de: ' + link['title'])
        
    except:
        print("Erro ao realizar download")
# Out:
# Download de: GAIA: uma proposta de um guia de recomendações de acessibilidade de interfaces Web com foco em aspectos do Autismo
# Download de: [PDF][PDF] Acessibilidade em governo eletrônico: um estudo sobre a aplicação de padrões Web em sítios gov. br
# Download de: Análise sobre o website Facebook do ponto de vista da acessibilidade
# Download de: Web accessibility: Study of maturity level of Portuguese institutions of higher education
# Erro ao realizar download
# Download de: Usabilidade, acessibilidade e qualidade da web da Administração Pública portuguesa
# Download de: Acessibilidade em websites de comércio eletrônico: avaliação através da interação com usuários cegos na Paraíba
# Download de: A acessibilidade nos sites do Poder Executivo estadual à luz dos direitos fundamentais das pessoas com deficiência
# Download de: Design responsivo e acessibilidade para dispositivos moveis: uma revisão sistemática de literatura
# Download de: Acessibilidade em portais de Governo Eletrônico do Poder Judiciário| Accessibility in e-government portals of the Judiciary
# Download de: [PDF][PDF] Acessibilidade da Plataforma Social Educativa Edmodo na perspectiva do deficiente visual
# Download de: [PDF][PDF] Compreensão de diretrizes de acessibilidade para criação de objetos de aprendizagem por meio de uma representação gráfica de síntese
# Download de: [PDF][PDF] Acessibilidade digital: Uma análise em portais de Instituições Federais de Educação do Brasil
# Download de: [PDF][PDF] Um estudo das recomendaçoes de acessibilidade para audiogames móveis
# Download de: [PDF][PDF] Acessibilidade virtual: Um estudo acerca da acessibilidade, usabilidade e comunicabilidade em portais institucionais federais
# Download de: [PDF][PDF] Recomendações de usabilidade e acessibilidade para interface de telefone celular visando o público idoso
# Erro ao realizar download
# Download de: Acessibilidade e Inclusão Digital de Cegos e Surdos em Plataformas Web: um estudo de caso
# Download de: ASPECTOS DE ACESSIBILIDADE DO GOVERNO ELETRÔNICO: Avaliação de portais web com ênfase em portadores de deficiência visual
# Download de: Cenários prospectivos com base nos projetos de lei para acessibilidade na web no Brasil
# Download de: Usabilidade e acessibilidade no Repositório de Informação Acessível da UFRN: avaliação ergonômica de interfaces Web
# Download de: [PDF][PDF] Acessibilidade do whatsapp sob a perspectiva de pessoas com deficiência visual
# Download de: [PDF][PDF] Análise de acessibilidade no Ambiente Virtual de Aprendizagem SOLAR–Um estudo de caso para usuários com deficiência visual
# Download de: Acessibilidade em Websites de Instituições Escolares com foco no Atendimento aos Usuários Surdos
# Download de: Avaliação dos níveis de acessibilidade das páginas e catálogos bibliográficos das bibliotecas de instituições do ensino superior
# Download de: [PDF][PDF] O que não podia ser visto, agora pode: acessibilidade de pessoas com deficiência visual às plataformas audiovisuais
# Download de: [PDF][PDF] Métodos, Técnicas e Ferramentas de Processos de Usabilidade Alinhado com as Diretrizes de Acessibilidade: Uma Revisão Sistemática da Literatura
# Download de: E-Acessibilidade na transparência ativa: a aplicação das tecnologias para implementação da Lei de Acesso à Informação
# Download de: Fatores críticos de sucesso na oferta de produtos e serviços de informação na Web.
# Download de: As bibliotecas universitárias no apoio a estudantes com Necessidades Educativas Especiais: acessibilidade das páginas e serviços disponibilizados na Internet
# Download de: [PDF][PDF] O desenvolvimento WEB no processo de ensino e aprendizado de química para deficientes visuais
# Download de: Destino Turístico Inteligente: Acessibilidade no Centro Histórico de São Luís–Maranhão, um estudo sobre a Reputação Online no TripAdvisor
# Download de: Recomendações de acessibilidade para surdos dos tipos de questões usadas na avaliação baseada em computador em ambientes virtuais de aprendizagem
# Download de: [PDF][PDF] Acessibilidade Comunicativa em Libras: Possibilidades a partir do Desenvolvimento de um Software
# Download de: A usabilidade e acessibilidade de um ambiente virtual de aprendizagem com foco no usuário idoso: uma verificação ergonômica do Moodle
# Download de: [PDF][PDF] Accessibility and Digital Inclusion: Utopia or a Great Challenge?
# Download de: Acessibilidade Informacional de Pcd no Contexto da Lei de Acesso à Informação: Desafios para estudo de usuários
# Download de: [PDF][PDF] Web Semantica, Agentes Inteligentes e a Produção de Conhecimento na Web 3.0
# Download de: Adequação de objetos de aprendizagem da disciplina de Redes de Computadores para a inserção de acessibilidade
# Download de: [PDF][PDF] ACESSIBILIDADE INFORMACIONAL NA BIBILIOTECA UNIVERSITÁRIA: EM FOCO O ALUNO COM DEFICÊNCIA
# Download de: Acessibilidade em websites de comércio eletrônico: avaliação através da interação com usuários cegos.
# Download de: [PDF][PDF] Acessibilidade para pessoas com deficiência visual em cursos no Moodle: guia para professores
# Download de: O Compartilhamento do Conhecimento para a Acessibilidade e Inclusão do Surdo: o teatro como mídia
# Download de: Acessibilidade informacional: um estudo sobre configurações de segurança em objetos digitais acessíveis segundo análise de aceitação por pessoas com …
# Download de: [PDF][PDF] Jornalismo e acessibilidade: TV INES, primeira webtv acessível do Brasil
# Download de: [PDF][PDF] 5. PROJETO DE ACESSIBILIDADE VIRTUAL
# Download de: Tecnologia acessível: reflexões sobre a utilização de recursos tecnológicos sonoros como acessibilidade aos textos literários para o aprendiz com deficiência visual
# Download de: Tecnologia assistiva para acessibilidade de pessoas com deficiência visual a ambientes virtuais de aprendizagem
# Download de: BRAVO Sistema Web de apoio à pesquisa em Educação
# Download de: Informação móvel para todos: acessibilidade em aplicativos jornalísticos para dispositivos móveis
# Download de: [PDF][PDF] Acessibilidade espacial no centro histórico de Santos (Brasil): as dificuldades enfrentadas pelos idosos
# Download de: Modelos de rede de transporte público e individual para estudos de acessibilidade em São Paulo.
# Download de: Acessibilidade para usuários da informação com deficiência: um estudo de artigos em Biblioteconomia e Ciência da Informação
# Download de: Menus de navegação em aplicações web para dispositivos móveis: questões de acesso e usabilidade
# Erro ao realizar download
# Download de: Dos modelos televisuais em vídeos na Web: desdobramentos midiáticos do programa de receita culinária
# Download de: [PDF][PDF] ACESSIBILIDADE ESPACIAL NO CENTRO HISTÓRICO DE POÇOS DE CALDAS (BRAZIL)
# Download de: Acessibilidade em unidades de informação e cultura: um estudo na Fundação Espaço Cultural da Paraíba (FUNESC)
# Download de: [PDF][PDF] … da interface para pessoas com deficiência visual através de recursos em smartphones: Uma perspectiva do design da informação sobre a acessibilidade …
# Download de: As tecnologias associadas ao conceito de Web 2.0
# Download de: A Vigilância Lateral e Participativa na Web 2.0
# Download de: [PDF][PDF] Turismo e Hospitalidade: um estudo sobre a acessibilidade para o turista da terceira idade nos bares e restaurantes de Brasília
# Download de: Entre a intenção e o gesto: discursos e práticas sobre acessibilidade em museus
# Download de: Turismo e Mobilidade: um diagnóstico da acessibilidade geográfica à fronteira Chuí-Rio Grande do Sul/RS, Brasil/Chuy, Uruguai
# Download de: [PDF][PDF] Rumo à uma Biblioteca de Sons Aberta para Experimentação Musical Coletiva na Web
# Download de: [PDF][PDF] DIRETRIZES ACESSÍVEIS EM AMBIENTES DIGITAIS: Aplicação de parâmetros gráfico-inclusivos para o desenvolvimento de sites
# Download de: Design Conectado: por um mundo de experiências
